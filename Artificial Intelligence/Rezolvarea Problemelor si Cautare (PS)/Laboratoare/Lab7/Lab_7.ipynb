# %% [markdown]
# **Knapsack Problem**
#
# Rezolvati problema rucsacului folosind algoritmi genetici.
# Presupun ca stiti enuntul problemei - ideea este sa maximizati value luand iteme din items fara sa depasiti limita maxima de greutate admisa.

# %%
ITEMS = [
    {"name": "Tent", "weight": 5.0, "value": 80},
    {"name": "Sleeping Bag", "weight": 2.0, "value": 70},
    {"name": "Water Filter", "weight": 0.5, "value": 90},
    {"name": "First Aid Kit", "weight": 1.0, "value": 85},
    {"name": "Stove", "weight": 1.5, "value": 60},
    {"name": "Fuel", "weight": 0.8, "value": 40},
    {"name": "Steak", "weight": 2.5, "value": 95},
    {"name": "Flashlight", "weight": 0.3, "value": 50},
    {"name": "Batteries", "weight": 0.2, "value": 30},
    {"name": "Knife", "weight": 0.4, "value": 55},
    {"name": "Rope", "weight": 1.0, "value": 45},
    {"name": "Jacket", "weight": 1.2, "value": 75},
    {"name": "Boots", "weight": 1.8, "value": 65},
    {"name": "Map", "weight": 0.1, "value": 40},
    {"name": "Compass", "weight": 0.1, "value": 35},
    {"name": "Solar Charger", "weight": 0.7, "value": 45},
    {"name": "Radio", "weight": 0.6, "value": 30},
    {"name": "Beer", "weight": 0.3, "value": 50},
    {"name": "Tarp", "weight": 1.1, "value": 40},
    {"name": "Bug Spray", "weight": 0.2, "value": 20}
]
WEIGHT_LIMIT = 10

# %%
import random

def make_candidate(): #face un candidat random
    return [random.randint(0, 1) for _ in range(len(ITEMS))]

def fitness(candidate): #chiar se recomanda a se hardcoda un fitness minim posibil daca depasiti weight-ul maxim.
    pass

def mutation(candidate): #perturbare random

def crossover(parent1, parent2): #facem niste interschimbari
    pass

def full_genetic_alg():
    #faceti populatia initiala, printati top candidates si fitnessurile lor, selectia(pastrati k% din cei mai buni), apoi repopulati(crossover&mutation)
